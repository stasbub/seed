# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
project_tod_purchases = pd.read_csv('/home/user/Documents/analytical_tasks/DOW&TOD/project_tod_purchases.csv')
project_tod_purchases.head()
# Out:
#       project  date_par    num
# 0  aviata_air         6   3059
# 1  aviata_air         7   5633
# 2  aviata_air         8  12308
# 3  aviata_air         9  25922
# 4  aviata_air        10  42148

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=project_tod_purchases, x='date_par', y='num', hue='project', palette='colorblind')
# Out:
# <AxesSubplot: xlabel='date_par', ylabel='num'>

# %%
project_tod_purchases_superapp = pd.read_csv('/home/user/Documents/analytical_tasks/DOW&TOD/project_tod_purchases_superapp.csv')
project_tod_purchases_superapp.head()
# Out:
#       project  date_par   num
# 0  aviata_air         0  2181
# 1  aviata_air         1  1270
# 2  aviata_air         2   717
# 3  aviata_air         3   356
# 4  aviata_air         4   171

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=project_tod_purchases_superapp, x='date_par', y='num', hue='project', palette='colorblind')
# Out:
# <AxesSubplot: xlabel='date_par', ylabel='num'>
