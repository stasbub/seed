# %%
import pandas as pd
import seaborn as sns

# %%
project_tod_purchases = pd.read_csv('/home/user/Documents/analytical_tasks/DOW&TOD/project_tod_purchases.csv')
project_tod_purchases.head()
# Out:
#       project  date_part    num
# 0  aviata_air          9  59348
# 1  aviata_air         11  55024
# 2  aviata_air         22   3094
# 3  aviata_air         18  32960
# 4  aviata_air          3  25510

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=project_tod_purchases, x='date_part', y='num', hue='project')
# Out:
# <AxesSubplot: xlabel='date_part', ylabel='num'>
