# %%
import pandas as pd
import seaborn as sns

# %%
project_dow_purchases = pd.read_csv('/home/user/Documents/analytical_tasks/DOW&TOD/project_dow_purchases.csv')
project_dow_purchases.head()
# Out:
#       project  num_day   name_day     num
# 0  aviata_air      0.0  Sunday      93136
# 1  aviata_air      1.0  Monday     131037
# 2  aviata_air      2.0  Tuesday    135728
# 3  aviata_air      3.0  Wednesday  134648
# 4  aviata_air      4.0  Thursday   138058

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=project_dow_purchases, x='name_day', y='num', hue='project')
# Out:
# <AxesSubplot: xlabel='name_day', ylabel='num'>
