# %%
import pandas as pd
import seaborn as sns

# %%
registered_no_1C_within_a_day = pd.read_csv('/home/user/Documents/analytical_tasks/Research/1C/registered_no_1C_within_a_day.csv', parse_dates=['month_time'])
registered_no_1C_within_a_day.head()
# Out:
#   month_time  num_users
# 0 2022-12-01       1348
# 1 2022-11-01       4548
# 2 2022-10-01       6684
# 3 2022-09-01       5302
# 4 2022-08-01       6391

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.lineplot(data=registered_no_1C_within_a_day.query("month_time >'2021-12-01'"), x='month_time', y='num_users')
# Out:
# <AxesSubplot: xlabel='month_time', ylabel='num_users'>

# %%
registered_no_1C_within_a_day.query("month_time >'2021-12-01'").num_users.mean()
# Out:
# 4434.333333333333
