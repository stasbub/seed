# %%
import pandas as pd
import seaborn as sns

# %%
registered_no_1C_within_a_day = pd.read_csv('/home/user/Documents/analytical_tasks/Research/1C/registered_no_1C_within_a_day.csv', parse_dates=['month_time'])
registered_no_1C_within_a_day.head()
# Out:
#   month_time  num_users
# 0 2022-12-01       2563
# 1 2022-11-01       7318
# 2 2022-10-01       9270
# 3 2022-09-01       6481
# 4 2022-08-01       7785

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.lineplot(data=registered_no_1C_within_a_day.query("month_time !='1970-01-01'"), x='month_time', y='num_users')
# Out:
# <AxesSubplot: xlabel='month_time', ylabel='num_users'>

# %%
registered_no_1C_within_a_day.num_users.mean()
# Out:
# 13159.31111111111
